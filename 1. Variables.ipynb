# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# ## Strings

# %%
name = "Flora"

# %% [markdown]
# ## Integers

# %%
number = 18

# %% [markdown]
# ## Floats

# %%
another_number = 6.25

# %% [markdown]
# ## Lists

# %%
my_variables = [3, 2, 78]
my_variables[1]
# Out:
# 2

# %% [markdown]
# ##### Explanation
# Python starts counting from 0 --> that's why the result is 2 and not 3

# %%
my_variables = [3, 2, 78, 2]
my_variables[1]=52
my_variables
# Out:
# [3, 52, 78, 2]

# %% [markdown]
# ##### Explanation
# A sorban lévő első elemet arra változtatja, amit beírtam az egyenlőségjel után
# 2 --> 52

# %% [markdown]
# ## Tuples

# %%
shopping_list = ["apples", "pears", "bananas"]
shopping_tuple = ("apples", "pears", "bananas")

# %%
shopping_list[1]
# Out:
# 'pears'

# %%
shopping_tuple[1]
# Out:
# 'pears'

# %% [markdown]
# ##### Explanation
# Miért [] és nem ()?

# %%
shopping_list[1] = "grapes"
shopping_list
# Out:
# ['apples', 'grapes', 'bananas']

# %%
shopping_tuple[1]
shopping_tuple[1] = "grapes"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 shopping_tuple[1]
# ----> 2 shopping_tuple[1] = "grapes"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ##### Explanation
# Error, mert nem lehet megváltoztatni a touple-ban az elemeket

# %% [markdown]
# ## Sets

# %%
new_list = [4, 4, 7, 19, 21, "I am a string", 7.23]
my_set = set(new_list)
my_set
# Out:
# {19, 21, 4, 7, 7.23, 'I am a string'}

# %%
my_next_set = {3, 5, 7}
my_next_set
# Out:
# {3, 5, 7}

# %% [markdown]
# ## Dictionaries

# %%
my_pet = {'name': 'D2',
         'species': 'cat',
         'likes': 'sleeping', 
         'dislikes': 'loud noise', 
         'age': 10}

# %%
my_pet['age']
# Out:
# 10

# %%
items = ['grapes', 'skyr', 'milk', ['salt', 'pepper', 'cumin'], 'rice']
number = [1, 2, 7, 3]
priority = ['high', 'high', 'low', 'hight']

# %%
shopping = {'items': items, 
            'number': number,
            'priority': priority}

# %% [markdown]
# ##### Explanation
# defines whatever the values is

# %%
shopping['items']
# Out:
# ['grapes', 'skyr', 'milk', ['salt', 'pepper', 'cumin'], 'rice']

# %%
shopping['items'][2]
# Out:
# 'milk'

# %%
shopping['items'][2][0]
# Out:
# 'm'

# %% [markdown]
# ##### Explanation
# Miért a milk szó betűit írja és nem az allista elemeit?
