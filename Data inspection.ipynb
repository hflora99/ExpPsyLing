# %%
import pandas as pd

# %%
raw = pd.read_csv('/work/ExpP_2026/ExpPsyLing/combined_data.csv')

# %%
raw
# Out:
#        participant_id  component_num  url  meta               sender  \
# 0                  51              1  NaN   NaN              Wecome1
# 1                  51              1  NaN   NaN              Wecome2
# 2                  51              1  NaN   NaN              Wecome3
# 3                  51              1  NaN   NaN        Instructions1
# 4                  51              1  NaN   NaN      Instructions 1a
# ...               ...            ...  ...   ...                  ...
# 15632              69              1  NaN   NaN           Short Loop
# 15633              69              1  NaN   NaN                Break
# 15634              69              1  NaN   NaN       Short Sequence
# 15635              69              1  NaN   NaN  Experiment Sequence
# 15636              69              1  NaN   NaN                 root
#
#          sender_type sender_id    ended_on   duration  time_run  ...  \
# 0      canvas.Screen         1     timeout     499.56    3556.0  ...
# 1      canvas.Screen         2     timeout     499.52    4056.0  ...
# 2      canvas.Screen         3     timeout     499.52    4555.0  ...
# 3      canvas.Screen         4    response    9061.10    5061.0  ...
# 4      canvas.Screen         5    response    2279.00   14148.0  ...
# ...              ...       ...         ...        ...       ...  ...
# 15632      flow.Loop    12_1_0  completion   85426.00  131341.5  ...
# 15633  canvas.Screen    12_1_1    response     868.30  216786.9  ...
# 15634  flow.Sequence      12_1  completion   86318.40  131341.4  ...
# 15635  flow.Sequence        12  completion  183618.50   34044.0  ...
# 15636  flow.Sequence       NaN  completion  216385.18    1295.4  ...
#
#        response  response_action  prime  target condition  soa_condition  \
# 0           NaN              NaN    NaN     NaN       NaN            NaN
# 1           NaN              NaN    NaN     NaN       NaN            NaN
# 2           NaN              NaN    NaN     NaN       NaN            NaN
# 3           NaN         keypress    NaN     NaN       NaN            NaN
# 4           NaN         keypress    NaN     NaN       NaN            NaN
# ...         ...              ...    ...     ...       ...            ...
# 15632       NaN              NaN    NaN     NaN       NaN            NaN
# 15633       NaN  keypress(Space)    NaN     NaN       NaN            NaN
# 15634       NaN              NaN    NaN     NaN       NaN            NaN
# 15635       NaN              NaN    NaN     NaN       NaN            NaN
# 15636       NaN              NaN    NaN     NaN       NaN            NaN
#
#       congruence correct_response correctResponse correct
# 0            NaN              NaN             NaN     NaN
# 1            NaN              NaN             NaN     NaN
# 2            NaN              NaN             NaN     NaN
# 3            NaN              NaN             NaN     NaN
# 4            NaN              NaN             NaN     NaN
# ...          ...              ...             ...     ...
# 15632        NaN              NaN             NaN     NaN
# 15633        NaN              NaN             NaN     NaN
# 15634        NaN              NaN             NaN     NaN
# 15635        NaN              NaN             NaN     NaN
# 15636        NaN              NaN             NaN     NaN
#
# [15637 rows x 26 columns]

# %%
# raw.head(20)

# %%
# listing the column names
list(raw)
# Out:
# ['participant_id',
#  'component_num',
#  'url',
#  'meta',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %%
# listing the columns that we need from the list
cols = ['participant_id','sender','duration','response', 'condition', 'soa_condition', 'congruence', 'correct_response', 'correct', "target"]

# %%
df = raw[cols]

# %%
df
# Out:
#        participant_id               sender   duration response condition  \
# 0                  51              Wecome1     499.56      NaN       NaN
# 1                  51              Wecome2     499.52      NaN       NaN
# 2                  51              Wecome3     499.52      NaN       NaN
# 3                  51        Instructions1    9061.10      NaN       NaN
# 4                  51      Instructions 1a    2279.00      NaN       NaN
# ...               ...                  ...        ...      ...       ...
# 15632              69           Short Loop   85426.00      NaN       NaN
# 15633              69                Break     868.30      NaN       NaN
# 15634              69       Short Sequence   86318.40      NaN       NaN
# 15635              69  Experiment Sequence  183618.50      NaN       NaN
# 15636              69                 root  216385.18      NaN       NaN
#
#       soa_condition congruence correct_response correct target
# 0               NaN        NaN              NaN     NaN    NaN
# 1               NaN        NaN              NaN     NaN    NaN
# 2               NaN        NaN              NaN     NaN    NaN
# 3               NaN        NaN              NaN     NaN    NaN
# 4               NaN        NaN              NaN     NaN    NaN
# ...             ...        ...              ...     ...    ...
# 15632           NaN        NaN              NaN     NaN    NaN
# 15633           NaN        NaN              NaN     NaN    NaN
# 15634           NaN        NaN              NaN     NaN    NaN
# 15635           NaN        NaN              NaN     NaN    NaN
# 15636           NaN        NaN              NaN     NaN    NaN
#
# [15637 rows x 10 columns]

# %%
df = df[df["sender"] == "target"]

# %%
df
# Out:
#        participant_id  sender  duration response        condition  \
# 13                 51  target    843.38        n         practice
# 19                 51  target    593.04        m         practice
# 25                 51  target    559.18        m         practice
# 31                 51  target    653.76        n         practice
# 40                 51  target    520.14        m  Inc_Synth_Synth
# ...               ...     ...       ...      ...              ...
# 15606              69  target    699.20        m        Con_Synth
# 15612              69  target    580.20        n          Con_Nat
# 15618              69  target    577.90        m    Inc_Nat_Synth
# 15624              69  target    661.10        n    Inc_Synth_Nat
# 15630              69  target    709.20        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response correct target
# 13         practice     practice                n    True  SHEEP
# 19         practice     practice                m    True   BOAT
# 25         practice     practice                m    True  HOUSE
# 31         practice     practice                n    True  HORSE
# 40             long  incongruent                m    True  PIANO
# ...             ...          ...              ...     ...    ...
# 15606         short    congruent                m    True   BELT
# 15612         short    congruent                n    True  DAISY
# 15618         short  incongruent                m    True   SHED
# 15624         short  incongruent                n    True  HUSKY
# 15630         short  incongruent                n    True  PETAL
#
# [2356 rows x 10 columns]

# %%
sender_list = list(df["sender"])
set(sender_list)
# Out:
# {'target'}

# %%
df["sender"].unique()
# Out:
# <StringArray>
# ['target']
# Length: 1, dtype: str

# %%
# df = raw(cols)
# df = df[df["sender"] == "target"]
df = df[df["condition"] != "practice"]
df = df.drop(columns = ["sender"])

# %%
df
# Out:
#        participant_id  duration response        condition soa_condition  \
# 40                 51    520.14        m  Inc_Synth_Synth          long
# 47                 51    640.66        n      Inc_Nat_Nat          long
# 54                 51    597.74        n    Inc_Synth_Nat          long
# 61                 51    495.68        n          Con_Nat          long
# 68                 51    556.86        m    Inc_Nat_Synth          long
# ...               ...       ...      ...              ...           ...
# 15606              69    699.20        m        Con_Synth         short
# 15612              69    580.20        n          Con_Nat         short
# 15618              69    577.90        m    Inc_Nat_Synth         short
# 15624              69    661.10        n    Inc_Synth_Nat         short
# 15630              69    709.20        n      Inc_Nat_Nat         short
#
#         congruence correct_response correct target
# 40     incongruent                m    True  PIANO
# 47     incongruent                m   False   BULL
# 54     incongruent                n    True   GOAT
# 61       congruent                n    True   PEAR
# 68     incongruent                m    True  MOTOR
# ...            ...              ...     ...    ...
# 15606    congruent                m    True   BELT
# 15612    congruent                n    True  DAISY
# 15618  incongruent                m    True   SHED
# 15624  incongruent                n    True  HUSKY
# 15630  incongruent                n    True  PETAL
#
# [2280 rows x 9 columns]

# %%
# df ["accuracy"] = df ["response"] == df["correct_response"]
df.loc[df["target"] == "BULL", "correct_response"] = "n"

# %%
df
# Out:
#        participant_id  duration response        condition soa_condition  \
# 40                 51    520.14        m  Inc_Synth_Synth          long
# 47                 51    640.66        n      Inc_Nat_Nat          long
# 54                 51    597.74        n    Inc_Synth_Nat          long
# 61                 51    495.68        n          Con_Nat          long
# 68                 51    556.86        m    Inc_Nat_Synth          long
# ...               ...       ...      ...              ...           ...
# 15606              69    699.20        m        Con_Synth         short
# 15612              69    580.20        n          Con_Nat         short
# 15618              69    577.90        m    Inc_Nat_Synth         short
# 15624              69    661.10        n    Inc_Synth_Nat         short
# 15630              69    709.20        n      Inc_Nat_Nat         short
#
#         congruence correct_response correct target
# 40     incongruent                m    True  PIANO
# 47     incongruent                n   False   BULL
# 54     incongruent                n    True   GOAT
# 61       congruent                n    True   PEAR
# 68     incongruent                m    True  MOTOR
# ...            ...              ...     ...    ...
# 15606    congruent                m    True   BELT
# 15612    congruent                n    True  DAISY
# 15618  incongruent                m    True   SHED
# 15624  incongruent                n    True  HUSKY
# 15630  incongruent                n    True  PETAL
#
# [2280 rows x 9 columns]

# %%
df["accuracy"] = df["response"] == df["correct_response"]

# %%
df
# Out:
#        participant_id  duration response        condition soa_condition  \
# 40                 51    520.14        m  Inc_Synth_Synth          long
# 47                 51    640.66        n      Inc_Nat_Nat          long
# 54                 51    597.74        n    Inc_Synth_Nat          long
# 61                 51    495.68        n          Con_Nat          long
# 68                 51    556.86        m    Inc_Nat_Synth          long
# ...               ...       ...      ...              ...           ...
# 15606              69    699.20        m        Con_Synth         short
# 15612              69    580.20        n          Con_Nat         short
# 15618              69    577.90        m    Inc_Nat_Synth         short
# 15624              69    661.10        n    Inc_Synth_Nat         short
# 15630              69    709.20        n      Inc_Nat_Nat         short
#
#         congruence correct_response correct target  accuracy
# 40     incongruent                m    True  PIANO      True
# 47     incongruent                n   False   BULL      True
# 54     incongruent                n    True   GOAT      True
# 61       congruent                n    True   PEAR      True
# 68     incongruent                m    True  MOTOR      True
# ...            ...              ...     ...    ...       ...
# 15606    congruent                m    True   BELT      True
# 15612    congruent                n    True  DAISY      True
# 15618  incongruent                m    True   SHED      True
# 15624  incongruent                n    True  HUSKY      True
# 15630  incongruent                n    True  PETAL      True
#
# [2280 rows x 10 columns]

# %%
df_grouped = df.groupby(["soa_condition", "congruence"]).mean(["duration"])
df_grouped
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df_grouped = df.groupby(["soa_condition", "congruence"]).mean(["duration"])
#       2 df_grouped
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1777, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1764 @final
#    1765 def _cython_agg_general(
#    1766     self,
#    (...)   1773     # Note: we never get here with how="ohlc" for DataFrameGroupBy;
#    1774     #  that goes through SeriesGroupBy
#    1776     if not is_bool(numeric_only):
# -> 1777         raise ValueError("numeric_only accepts only Boolean values")
#    1779     data = self._get_data_to_aggregate(numeric_only=numeric_only, name=how)
#    1781     def array_func(values: ArrayLike) -> ArrayLike:
#
# ValueError: numeric_only accepts only Boolean values

# %%
df_grouped = df_grouped.reset_index()
df_grouped
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df_grouped = df_grouped.reset_index()
#       2 df_grouped
#
# NameError: name 'df_grouped' is not defined

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
ax = sns.barplot(data = df_grouped, x = "soa_condition", y = "duartion", hue = "soa_condition")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 ax = sns.barplot(data = df_grouped, x = "soa_condition", y = "duartion", hue = "soa_condition")
#
# NameError: name 'sns' is not defined
